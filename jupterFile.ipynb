# %% [markdown]
# ### Print 'Hello' Word:

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ### Machine Learning:
#    getting data, analysing that and then use it to do some pridection called ml

# %%
def full_name(first, last):
    print(f"MY full name is {first} {last}")

full_name('ahmad', 'datin')
# Out:
# MY full name is ahmad datin

# %%
name = 'adil'
print(name.upper())
age = 22
print(age)
# Out:
# ADIL
# 22

# %% [markdown]
# ### Exceptions

# %%
try:
    name = input("What is your name? ")
    print(name)
except ValueError:
    print("Invalid input")

# %%
print("my name is Adil shah")
print("my name is Ahmad Dateen bello")
name = "my  name is adil shah"

# %% [markdown]
# ### Random access using random module

# %%
import random

members = ['Shehi', 'Good boy', 'Jafar', 'Ingawa', 'Dateen']
leader = random.choice(members)
print(f'Among this list your leader is {leader}')
for i in members:
    print(i)
# Out:
# Among this list your leader is Jafar
# Shehi
# Good boy
# Jafar
# Ingawa
# Dateen

# %% [markdown]
# ### Roll dice
# class : Dice
# method : roll and the roll should be a tuple

# %%
import random
class Dice():
    def roll(self):
        first  = random.randint(1,6)
        second = random.randint(1,6)
        return first, second


dice1 = Dice()
dice1.roll()
# Out:
# (1, 2)

# %% [markdown]
# ### working with real data set from kaggle

# %%
import pandas as pd
df = pd.read_csv('vgsales.csv')
df.shape
# Out:
# (16598, 11)

# %% [markdown]
# ### making new music model

# %%
# 1. Import tools
import pandas as pd                    # For reading data
from sklearn.tree import DecisionTreeClassifier  # For ML model

# 2. Load data
music_data = pd.read_csv('music.csv')  # Read the CSV file


# 3. Prepare data
X = music_data.drop(columns=['genre']) # Features: Age, Gender
y = music_data['genre']                # Target: Genre

# 4. Create and train model
model = DecisionTreeClassifier()       # Create empty model
model.fit(X, y)                        # Train it

# 5. Make predictions
predictions = model.predict([[21, 1], [22, 0], [30, 1], [30, 0]])  # Predict for 4 people

# 6. Show results
print(predictions)                     # Output: ['HipHop' 'Dance']
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical
# ['HipHop' 'Dance' 'Jazz' 'Acoustic']
# c:\Users\ahmad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
